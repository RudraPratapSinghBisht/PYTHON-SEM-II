# %% [markdown]
# <a href="https://colab.research.google.com/github/RudraPratapSinghBisht/PYTHON-SEM-II/blob/main/EXPERIMENT3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
print("---------------------------")
a=int(input("Enter a number : "))
if a%3 == 0 and a%5 == 0 :
  print("It is divisible by 3 and 5 both")
else :
  print("It is not divisible by 3 and 5 both")

#2
print("---------------------------")
b=int(input("Enter a number : "))
if b%5 == 0 :
  print("It is a multiple of 5")
else :
  print("It is not a multiple of 5")

#3
print("---------------------------")
print("Enter two numbers")
c=int(input())
d=int(input())
if c>d :
  print(c,"is greater than",d)
elif d>c :
  print(d,"is greater than",c)
else :
  print(c,"is equal to",d)

#4
print("---------------------------")
print("Enter three numbers")
e=int(input())
f=int(input())
g=int(input())
if e > f and e > g:
  print(e, "is the greatest")
elif f > e and f > g:
  print(f, "is the greatest")
else:
  print(g, "is the greatest")

#5
print("---------------------------")
import cmath
a1 = float(input("Enter the coefficient of x^2: "))
b1 = float(input("Enter the coefficient of x: "))
c1 = float(input("Enter the constant term: "))
dis = (b1*2) - 4*(a1*c1)
if dis>0 :
 print("Roots are real and distinct\n")
 x1 = (-b1 - (dis**0.5)) / (2*a1)
 x2 = (-b1 + (dis**0.5)) / (2*a1)
 print(x1,x2)
elif dis==0 :
 print("Roots are real and equal")
 x1 = (-b1 - (dis**0.5)) / (2*a1)
 x2 = (-b1 + (dis**0.5)) / (2*a1)
 print(x1,x2)
else :
 print("Roots are complex and distinct")
 x1 = (-b1 - (dis**0.5)) / (2*a1)
 x2 = (-b1 + (dis**0.5)) / (2*a1)
 print(x1,x2)

#6
print("---------------------------")
year = int(input("Enter a year: "));
if year % 4 != 0:
  print(f"{year} is not a leap year.")
elif year % 100 == 0:
  if year % 400 == 0:
    print(f"{year} is a leap year.")
  else:
    print(f"{year} is not a leap year.")
else:
  print(f"{year} is a leap year.")

#7
print("---------------------------")
day = int(input("Enter day : "))
month = int(input("Enter month : "))
year = int(input("Enter year : "))
is_leap = (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)
days_in_month = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
if is_leap:
    days_in_month[1] = 29
day += 1
if day > days_in_month[month - 1]:
    day = 1
    month += 1
    if month > 12:
        month = 1
        year += 1
print(f"Next date: day={day}, month={month}, year={year}")


#8
print("---------------------------")
name=input("Enter the name :")
roll=input("Enter the roll :")
sap=input("Enter the SAP ID :")
sem=1
course = "Btech CSE"
print("Enter marks of five subjects")
pds=float(input("Enter marks of PDS :"))
pyth=float(input("Enter marks of Python :"))
chem=float(input("Enter marks of Chemistry :"))
eng=float(input("Enter marks of English :"))
phy=float(input("Enter marks of Physics :"))
if pds<100 or pyth<100 or chem<100 or eng<100 or phy<100 :
 per=((pds+pyth+chem+eng+phy)/500)*100
 cgpa = per/10
 if cgpa>=0 and cgpa<3.5 :
  grade= "F"
 elif cgpa>=3.5 and cgpa<=5.0 :
  grade= "C+"
 elif cgpa>=5.1 and cgpa<=6.0 :
  grade = "B"
 elif cgpa>=6.1 and cgpa<=7.0 :
  grade="B+"
 elif cgpa>=7.1 and cgpa<=8.0 :
  grade="A"
 elif cgpa>=8.1 and cgpa<9.0 :
  grade="A+"
 else :
  grade="O"
 print("SAMPLE GRADESHEET")
 print("Name : ",name)
 print("Roll no :",roll)
 print("SAP ID :",sap)
 print("SEM :",sem)
 print("COURSE :",course)
 print("PDS :",pds)
 print("PYTHON :",pyth)
 print("CHEMISTRY :",chem)
 print("ENGLISH :",eng)
 print("PHYSICS :",phy)
 print("percentage : " ,per)
 print("CGPA : " ,cgpa)
 print("GRADE :",grade)
else :
 print("Invalid input")
# Out:
# ---------------------------
# Enter a number : 45
# It is divisible by 3 and 5 both
# ---------------------------
# Enter a number : 4
# It is not a multiple of 5
# ---------------------------
# Enter two numbers
# 5
# 5
# 5 is equal to 5
# ---------------------------
# Enter three numbers
# 1
# 5
# 6
# 6 is the greatest
# ---------------------------
# Enter the coefficient of x^2: 4
# Enter the coefficient of x: 5
# Enter the constant term: 5
# Roots are complex and distinct
# (-0.6250000000000001-1.0458250331675945j) (-0.6249999999999999+1.0458250331675945j)
# ---------------------------
# Enter a year: 2006
# 2006 is not a leap year.
# ---------------------------
# Enter day : 4
# Enter month : 12
# Enter year : 2008
# Next date: day=5, month=12, year=2008
# ---------------------------
# Enter the name :rudra
# Enter the roll :12
# Enter the SAP ID :590016590
# Enter marks of five subjects
# Enter marks of PDS :45
# Enter marks of Python :56
# Enter marks of Chemistry :67
# ...
